# %%
number_1 = int(input("ENTER THE FIREST NUMBER"))
number_2 = int(input("ENTER THE SACND NUMBER"))
number_3 = int(input ("enter the therd number"))
sum=number_1+number_2+number_3
subtr=number_1-number_2-number_3
avrage=sum/3
x= min(number_1,number_2,number_3)
y= max(number_1,number_2,number_3)
print ( "sum=" , sum )
print("subtr=",subtr)
print("avrage=",avrage)
print("the min is=",x)
print("the max is=",y)
# Out:
# ENTER THE FIREST NUMBER1
# ENTER THE SACND NUMBER2
# enter the therd number3
# sum= 6
# subtr= -4
# avrage= 2.0
# the min is= 1
# the max is= 3
